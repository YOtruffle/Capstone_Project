# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Fitness is a growing trend, especially across the Middle East. The combination of having to constantly look good on social media and the healthy revolution has led to a significant increase in the number of those joining gyms, many of whom would not traditionally do so. In addition as COVID-19 linked lockdowns begin to ease, people are likely to flock to gyms and fitness centres to shed the pounds gained while stuck at home. Location is central to which gym people choose, nobody wants a half-hour commute for a workout. As of such I will leverage Foursquare API data to find the areas in Beirut, the capital of Lebanon, that are most underserved with fitness centres and use that as a proxy for where the optimal location for a new gym would be.

# %% [markdown]
# ## Data

# %% [markdown]
# Complete data on Lebanon is scarce; few people collect or update it. As of such my ability to work with the Foursquare API is limited as many locations do not have a category or are missing some other entry. That said, the most complete list I could find was that of gyms and fitness centres and hence that is what data I will use.

# %% [markdown]
# ## Process

# %% [markdown]
# To figure out which areas in Beirut are most underserved I'll first plot all fitness centres on a map and use such to qualitatively figure out which areas would be best served by a new gym.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ZF1BTD4OS3INYB1FQLKAK53W1S0SFVVCGZIPNKEHGQ1OHVME' # your Foursquare ID
CLIENT_SECRET = '3QVK0RDV12UMU3RX3BOXUYC0OTB2HXOB3OWNETO3ET0OK43N' # your Foursquare Secret
VERSION = '20200000'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZF1BTD4OS3INYB1FQLKAK53W1S0SFVVCGZIPNKEHGQ1OHVME
# CLIENT_SECRET:3QVK0RDV12UMU3RX3BOXUYC0OTB2HXOB3OWNETO3ET0OK43N

# %%
address = 'Mar Antonios Street, Beirut'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.8942938 35.5129043

# %%
search_query = 'Fitness'
radius = 10000000
print(search_query + ' .... OK!')
# Out:
# Fitness .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZF1BTD4OS3INYB1FQLKAK53W1S0SFVVCGZIPNKEHGQ1OHVME&client_secret=3QVK0RDV12UMU3RX3BOXUYC0OTB2HXOB3OWNETO3ET0OK43N&ll=33.8942938,35.5129043&v=20200000&query=Fitness&radius=10000000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed4cbc47828ae001b3b7c69'},
#  'response': {'venues': [{'id': '5641bb4738fa012315fc9840',
#     'name': 'Fitness Zone at The Souks',
#     'location': {'address': 'Beirut Souks',
#      'lat': 33.89952691454219,
#      'lng': 35.50350666585211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89952691454219,
#        'lng': 35.50350666585211}],
#      'distance': 1045,
#      'cc': 'LB',
#      'city': 'Beirut Souks - Beirut Central District | Downtown',
#      'country': 'لبنان',
#      'formattedAddress': ['Beirut Souks',
#       'Beirut Souks - Beirut Central District | Downtown',
#       'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '52655d77498e67a4e2929aae',
#     'name': 'GT fitness',
#     'location': {'lat': 33.89365011885825,
#      'lng': 35.51223030257376,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89365011885825,
#        'lng': 35.51223030257376}],
#      'distance': 94,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '523da48b11d23025a7aba955',
#     'name': 'cross fitness',
#     'location': {'address': 'gemayzeh',
#      'lat': 33.894222259521484,
#      'lng': 35.51161575317383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.894222259521484,
#        'lng': 35.51161575317383}],
#      'distance': 119,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['gemayzeh', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4f9a9edce4b0edc560069fb3',
#     'name': 'Fitness Zone Cofé',
#     'location': {'address': 'Crown Plaza',
#      'crossStreet': 'Hamra',
#      'lat': 33.896133736279126,
#      'lng': 35.47947909299027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.896133736279126,
#        'lng': 35.47947909299027}],
#      'distance': 3095,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Crown Plaza (Hamra)', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '58d8e18bd7b47305c43f348d',
#     'name': 'Fitness Zone At ABC',
#     'location': {'lat': 33.888545,
#      'lng': 35.519445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.888545,
#        'lng': 35.519445}],
#      'distance': 880,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '58d8e0d7ca10707e5751e05c',
#     'name': 'Fitness Zone At ABC',
#     'location': {'lat': 33.888653,
#      'lng': 35.519371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.888653,
#        'lng': 35.519371}],
#      'distance': 866,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '5b2666a71ffe97002c155007',
#     'name': 'Tactical Fitness',
#     'location': {'address': 'Rafic Salloum Street',
#      'lat': 33.884712,
#      'lng': 35.544267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.884712,
#        'lng': 35.544267}],
#      'distance': 3088,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Rafic Salloum Street', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4de321a28877bcb68655f3c5',
#     'name': 'Fitness Zone',
#     'location': {'lat': 33.89559742654037,
#      'lng': 35.49611840098693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89559742654037,
#        'lng': 35.49611840098693}],
#      'distance': 1557,
#      'cc': 'LB',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '547de6d9498ef97a10cfed87',
#     'name': '180 Degrees Fitness & Spa',
#     'location': {'address': 'BirHassan - Marriott Jnah Highway(Next To Oman Embassy)',
#      'crossStreet': 'BirHassan Highway',
#      'lat': 33.8711602580186,
#      'lng': 35.48658852033742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.8711602580186,
#        'lng': 35.48658852033742}],
#      'distance': 3542,
#      'cc': 'LB',
#      'city': 'BirHassan - Jnah 💪',
#      'country': 'لبنان',
#      'formattedAddress': ['BirHassan - Marriott Jnah Highway(Next To Oman Embassy) (BirHassan Highway)',
#       'BirHassan - Jnah 💪',
#       'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '54662dbd498e7e8a014dbbd9',
#     'name': 'Hi-tec fitness. Starco',
#     'location': {'address': 'Starco',
#      'lat': 33.898606,
#      'lng': 35.500808,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.898606,
#        'lng': 35.500808}],
#      'distance': 1216,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['Starco', 'لبنان']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4fd0393fe4b01b683f44006d',
#     'name': 'Audi Fitness',
#     'location': {'address': 'Audi Plaza',
#      'lat': 33.898716465837325,
#      'lng': 35.501209530026145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.898716465837325,
#        'lng': 35.501209530026145}],
#      'distance': 1187,
#      'cc': 'LB',
#      'city': 'Bab Idriss',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Audi Plaza', 'باب ادريس', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '582aae2f7532c85d707b5ace',
#     'name': 'Fitness Bar',
#     'location': {'address': 'Next to AUH',
#      'crossStreet': 'AUH',
#      'lat': 33.897265,
#      'lng': 35.485352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.897265,
#        'lng': 35.485352}],
#      'distance': 2567,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Next to AUH (AUH)', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d112941735',
#       'name': 'Juice Bar',
#       'pluralName': 'Juice Bars',
#       'shortName': 'Juice Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4f510162e4b02b3bcace3c68',
#     'name': 'Fitness Plus',
#     'location': {'lat': 33.88453811479719,
#      'lng': 35.49012150727748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.88453811479719,
#        'lng': 35.49012150727748}],
#      'distance': 2368,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '594a2c9c464d653372c25900',
#     'name': 'Fitness Zone Verdun',
#     'location': {'lat': 33.885956,
#      'lng': 35.483206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.885956,
#        'lng': 35.483206}],
#      'distance': 2897,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4d84b44981fdb1f7c62701c0',
#     'name': 'Fitness corner',
#     'location': {'address': 'Qoraitem',
#      'lat': 33.89565073780514,
#      'lng': 35.48322336807702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89565073780514,
#        'lng': 35.48322336807702}],
#      'distance': 2746,
#      'cc': 'LB',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Qoraitem', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4baa68a1f964a5205b673ae3',
#     'name': 'Fitness first',
#     'location': {'lat': 33.895506,
#      'lng': 35.4826974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.895506,
#        'lng': 35.4826974}],
#      'distance': 2794,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '5294851611d2879d4c714a4f',
#     'name': 'Fitness Corner Sports Club',
#     'location': {'address': 'Kreytim',
#      'lat': 33.892400806757585,
#      'lng': 35.47690693338012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.892400806757585,
#        'lng': 35.47690693338012}],
#      'distance': 3332,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['Kreytim', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '5c3f5eb24a1cc0002cd18f87',
#     'name': 'Fitness Zone',
#     'location': {'address': 'Manara, Dalfa Center',
#      'lat': 33.900433,
#      'lng': 35.472521,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.900433,
#        'lng': 35.472521}],
#      'distance': 3793,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Manara, Dalfa Center', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4c8e77b9daa93704acea4cb1',
#     'name': 'Fitness Zone',
#     'location': {'address': 'Hamra',
#      'crossStreet': 'Crowne plaza hotel',
#      'lat': 33.89593422706241,
#      'lng': 35.47950551089675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89593422706241,
#        'lng': 35.47950551089675}],
#      'distance': 3091,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Hamra (Crowne plaza hotel)', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '52fd0ddf498e4d337917c8d0',
#     'name': 'platinum fitness club',
#     'location': {'lat': 33.87697253584076,
#      'lng': 35.50733236624968,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.87697253584076,
#        'lng': 35.50733236624968}],
#      'distance': 1995,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4cf3f95fd29b2d43c453f3bb',
#     'name': 'Muscoli Fitness',
#     'location': {'address': 'Sanayeh',
#      'lat': 33.89321728137451,
#      'lng': 35.4912462338631,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89321728137451,
#        'lng': 35.4912462338631}],
#      'distance': 2004,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Sanayeh', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4f8c14e6e4b002b90dabb51f',
#     'name': 'Fitness Zone',
#     'location': {'address': 'Hazmieh',
#      'lat': 33.85263050912447,
#      'lng': 35.533100536582836,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.85263050912447,
#        'lng': 35.533100536582836}],
#      'distance': 4999,
#      'cc': 'LB',
#      'city': 'Mt Lebanon',
#      'country': 'لبنان',
#      'formattedAddress': ['Hazmieh', 'Mt Lebanon', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4e8f407393adc15b61950d21',
#     'name': 'Heart Beat Fitness Club',
#     'location': {'lat': 33.88999748580905,
#      'lng': 35.48908013816885,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.88999748580905,
#        'lng': 35.48908013816885}],
#      'distance': 2252,
#      'cc': 'LB',
#      'state': 'Mt Lebanon',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '589ec2d80bc55b3d8224ee1b',
#     'name': 'Fitness House',
#     'location': {'lat': 33.88502,
#      'lng': 35.562236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.88502,
#        'lng': 35.562236}],
#      'distance': 4674,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '55630503498e6647f30c1052',
#     'name': 'Fitness zone pool',
#     'location': {'address': 'Fitness Zone',
#      'lat': 33.852660090298116,
#      'lng': 35.533048576925786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.852660090298116,
#        'lng': 35.533048576925786}],
#      'distance': 4994,
#      'cc': 'LB',
#      'city': 'بعبدا',
#      'state': 'محافظة جبل لبنان',
#      'country': 'لبنان',
#      'formattedAddress': ['Fitness Zone', 'بعبدا', 'لبنان']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a28',
#       'name': 'Bathing Area',
#       'pluralName': 'Bathing Areas',
#       'shortName': 'Bathing Area',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4e0091ee1f6ef39c294048b3',
#     'name': 'Yemeco - The Fitness Company',
#     'location': {'lat': 33.896703,
#      'lng': 35.538875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.896703,
#        'lng': 35.538875}],
#      'distance': 2414,
#      'cc': 'LB',
#      'state': 'Mt Lebanon',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '597056e4033693233bb27723',
#     'name': 'Monday Fitness Studio',
#     'location': {'crossStreet': 'Verdun',
#      'lat': 33.882449,
#      'lng': 35.483537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.882449,
#        'lng': 35.483537}],
#      'distance': 3017,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Verdun', 'بيروت', 'لبنان']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4b2',
#       'name': 'Pilates Studio',
#       'pluralName': 'Pilates Studios',
#       'shortName': 'Pilates Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '523199cb11d279f8d29ad3f3',
#     'name': 'Gofit fitness club',
#     'location': {'address': 'Hamra',
#      'crossStreet': 'Bliss Street',
#      'lat': 33.89925223033421,
#      'lng': 35.48414871234065,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89925223033421,
#        'lng': 35.48414871234065}],
#      'distance': 2713,
#      'cc': 'LB',
#      'city': 'بيروت',
#      'state': 'محافظة بيروت',
#      'country': 'لبنان',
#      'formattedAddress': ['Hamra (Bliss Street)', 'بيروت', 'لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '4f441e12e4b06bcb6d7d4b2b',
#     'name': 'shape up, fitness club.',
#     'location': {'lat': 33.87421114403472,
#      'lng': 35.525099343215956,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.87421114403472,
#        'lng': 35.525099343215956}],
#      'distance': 2503,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False},
#    {'id': '51ed32b0498e58679fb93ee8',
#     'name': '360 Fitness',
#     'location': {'lat': 33.89275081137641,
#      'lng': 35.4878190627508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.89275081137641,
#        'lng': 35.4878190627508}],
#      'distance': 2324,
#      'cc': 'LB',
#      'country': 'لبنان',
#      'formattedAddress': ['لبنان']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591004188',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues).head(100)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(100)
# Out:
#                             name            categories  \
# 0      Fitness Zone at The Souks  Gym / Fitness Center
# 1                     GT fitness                   Gym
# 2                  cross fitness                   Gym
# 3              Fitness Zone Cofé                  Café
# 4            Fitness Zone At ABC  Gym / Fitness Center
# 5            Fitness Zone At ABC  Gym / Fitness Center
# 6               Tactical Fitness  Gym / Fitness Center
# 7                   Fitness Zone                   Gym
# 8      180 Degrees Fitness & Spa  Gym / Fitness Center
# 9         Hi-tec fitness. Starco    Athletics & Sports
# 10                  Audi Fitness  Gym / Fitness Center
# 11                   Fitness Bar             Juice Bar
# 12                  Fitness Plus                   Gym
# 13           Fitness Zone Verdun  Gym / Fitness Center
# 14                Fitness corner  Gym / Fitness Center
# 15                 Fitness first                   Gym
# 16    Fitness Corner Sports Club                   Gym
# 17                  Fitness Zone  Gym / Fitness Center
# 18                  Fitness Zone                   Gym
# 19         platinum fitness club    Athletics & Sports
# 20               Muscoli Fitness                   Gym
# 21                  Fitness Zone                   Gym
# 22       Heart Beat Fitness Club                   Gym
# 23                 Fitness House                   Gym
# 24             Fitness zone pool          Bathing Area
# 25  Yemeco - The Fitness Company                Office
# 26         Monday Fitness Studio        Pilates Studio
# 27            Gofit fitness club                   Gym
# 28       shape up, fitness club.                   Gym
# 29                   360 Fitness                   Gym
#
#                                               address        lat        lng  \
# 0                                        Beirut Souks  33.899527  35.503507
# 1                                                 NaN  33.893650  35.512230
# 2                                            gemayzeh  33.894222  35.511616
# 3                                         Crown Plaza  33.896134  35.479479
# 4                                                 NaN  33.888545  35.519445
# 5                                                 NaN  33.888653  35.519371
# 6                                Rafic Salloum Street  33.884712  35.544267
# 7                                                 NaN  33.895597  35.496118
# 8   BirHassan - Marriott Jnah Highway(Next To Oman...  33.871160  35.486589
# 9                                              Starco  33.898606  35.500808
# 10                                         Audi Plaza  33.898716  35.501210
# 11                                        Next to AUH  33.897265  35.485352
# 12                                                NaN  33.884538  35.490122
# 13                                                NaN  33.885956  35.483206
# 14                                           Qoraitem  33.895651  35.483223
# 15                                                NaN  33.895506  35.482697
# 16                                            Kreytim  33.892401  35.476907
# 17                               Manara, Dalfa Center  33.900433  35.472521
# 18                                              Hamra  33.895934  35.479506
# 19                                                NaN  33.876973  35.507332
# 20                                            Sanayeh  33.893217  35.491246
# 21                                            Hazmieh  33.852631  35.533101
# 22                                                NaN  33.889997  35.489080
# 23                                                NaN  33.885020  35.562236
# 24                                       Fitness Zone  33.852660  35.533049
# 25                                                NaN  33.896703  35.538875
# 26                                                NaN  33.882449  35.483537
# 27                                              Hamra  33.899252  35.484149
# 28                                                NaN  33.874211  35.525099
# 29                                                NaN  33.892751  35.487819
#
#                                        labeledLatLngs  distance  cc  \
# 0   [{'label': 'display', 'lat': 33.89952691454219...      1045  LB
# 1   [{'label': 'display', 'lat': 33.89365011885825...        94  LB
# 2   [{'label': 'display', 'lat': 33.89422225952148...       119  LB
# 3   [{'label': 'display', 'lat': 33.89613373627912...      3095  LB
# 4   [{'label': 'display', 'lat': 33.888545, 'lng':...       880  LB
# 5   [{'label': 'display', 'lat': 33.888653, 'lng':...       866  LB
# 6   [{'label': 'display', 'lat': 33.884712, 'lng':...      3088  LB
# 7   [{'label': 'display', 'lat': 33.89559742654037...      1557  LB
# 8   [{'label': 'display', 'lat': 33.8711602580186,...      3542  LB
# 9   [{'label': 'display', 'lat': 33.898606, 'lng':...      1216  LB
# 10  [{'label': 'display', 'lat': 33.89871646583732...      1187  LB
# 11  [{'label': 'display', 'lat': 33.897265, 'lng':...      2567  LB
# 12  [{'label': 'display', 'lat': 33.88453811479719...      2368  LB
# 13  [{'label': 'display', 'lat': 33.885956, 'lng':...      2897  LB
# 14  [{'label': 'display', 'lat': 33.89565073780514...      2746  LB
# 15  [{'label': 'display', 'lat': 33.895506, 'lng':...      2794  LB
# 16  [{'label': 'display', 'lat': 33.89240080675758...      3332  LB
# 17  [{'label': 'display', 'lat': 33.900433, 'lng':...      3793  LB
# 18  [{'label': 'display', 'lat': 33.89593422706241...      3091  LB
# 19  [{'label': 'display', 'lat': 33.87697253584076...      1995  LB
# 20  [{'label': 'display', 'lat': 33.89321728137451...      2004  LB
# 21  [{'label': 'display', 'lat': 33.85263050912447...      4999  LB
# 22  [{'label': 'display', 'lat': 33.88999748580905...      2252  LB
# 23  [{'label': 'display', 'lat': 33.88502, 'lng': ...      4674  LB
# 24  [{'label': 'display', 'lat': 33.85266009029811...      4994  LB
# 25  [{'label': 'display', 'lat': 33.896703, 'lng':...      2414  LB
# 26  [{'label': 'display', 'lat': 33.882449, 'lng':...      3017  LB
# 27  [{'label': 'display', 'lat': 33.89925223033421...      2713  LB
# 28  [{'label': 'display', 'lat': 33.87421114403472...      2503  LB
# 29  [{'label': 'display', 'lat': 33.89275081137641...      2324  LB
#
#                                                  city country  \
# 0   Beirut Souks - Beirut Central District | Downtown   لبنان
# 1                                                 NaN   لبنان
# 2                                                 NaN   لبنان
# 3                                               بيروت   لبنان
# 4                                               بيروت   لبنان
# 5                                               بيروت   لبنان
# 6                                               بيروت   لبنان
# 7                                                 NaN   لبنان
# 8                                  BirHassan - Jnah 💪   لبنان
# 9                                                 NaN   لبنان
# 10                                         Bab Idriss   لبنان
# 11                                              بيروت   لبنان
# 12                                                NaN   لبنان
# 13                                              بيروت   لبنان
# 14                                                NaN   لبنان
# 15                                                NaN   لبنان
# 16                                                NaN   لبنان
# 17                                              بيروت   لبنان
# 18                                              بيروت   لبنان
# 19                                                NaN   لبنان
# 20                                              بيروت   لبنان
# 21                                         Mt Lebanon   لبنان
# 22                                                NaN   لبنان
# 23                                                NaN   لبنان
# 24                                              بعبدا   لبنان
# 25                                                NaN   لبنان
# 26                                              بيروت   لبنان
# 27                                              بيروت   لبنان
# 28                                                NaN   لبنان
# 29                                                NaN   لبنان
#
#                                      formattedAddress         crossStreet  \
# 0   [Beirut Souks, Beirut Souks - Beirut Central D...                 NaN
# 1                                             [لبنان]                 NaN
# 2                                   [gemayzeh, لبنان]                 NaN
# 3                 [Crown Plaza (Hamra), بيروت, لبنان]               Hamra
# 4                                      [بيروت, لبنان]                 NaN
# 5                                      [بيروت, لبنان]                 NaN
# 6                [Rafic Salloum Street, بيروت, لبنان]                 NaN
# 7                                             [لبنان]                 NaN
# 8   [BirHassan - Marriott Jnah Highway(Next To Oma...   BirHassan Highway
# 9                                     [Starco, لبنان]                 NaN
# 10                     [Audi Plaza, باب ادريس, لبنان]                 NaN
# 11                  [Next to AUH (AUH), بيروت, لبنان]                 AUH
# 12                                            [لبنان]                 NaN
# 13                                     [بيروت, لبنان]                 NaN
# 14                                  [Qoraitem, لبنان]                 NaN
# 15                                            [لبنان]                 NaN
# 16                                   [Kreytim, لبنان]                 NaN
# 17               [Manara, Dalfa Center, بيروت, لبنان]                 NaN
# 18         [Hamra (Crowne plaza hotel), بيروت, لبنان]  Crowne plaza hotel
# 19                                            [لبنان]                 NaN
# 20                            [Sanayeh, بيروت, لبنان]                 NaN
# 21                       [Hazmieh, Mt Lebanon, لبنان]                 NaN
# 22                                            [لبنان]                 NaN
# 23                                            [لبنان]                 NaN
# 24                       [Fitness Zone, بعبدا, لبنان]                 NaN
# 25                                            [لبنان]                 NaN
# 26                             [Verdun, بيروت, لبنان]              Verdun
# 27               [Hamra (Bliss Street), بيروت, لبنان]        Bliss Street
# 28                                            [لبنان]                 NaN
# 29                                            [لبنان]                 NaN
#
#                state                        id
# 0                NaN  5641bb4738fa012315fc9840
# 1                NaN  52655d77498e67a4e2929aae
# 2                NaN  523da48b11d23025a7aba955
# 3       محافظة بيروت  4f9a9edce4b0edc560069fb3
# 4       محافظة بيروت  58d8e18bd7b47305c43f348d
# 5       محافظة بيروت  58d8e0d7ca10707e5751e05c
# 6       محافظة بيروت  5b2666a71ffe97002c155007
# 7       محافظة بيروت  4de321a28877bcb68655f3c5
# 8                NaN  547de6d9498ef97a10cfed87
# 9                NaN  54662dbd498e7e8a014dbbd9
# 10      محافظة بيروت  4fd0393fe4b01b683f44006d
# 11      محافظة بيروت  582aae2f7532c85d707b5ace
# 12               NaN  4f510162e4b02b3bcace3c68
# 13      محافظة بيروت  594a2c9c464d653372c25900
# 14      محافظة بيروت  4d84b44981fdb1f7c62701c0
# 15               NaN  4baa68a1f964a5205b673ae3
# 16               NaN  5294851611d2879d4c714a4f
# 17      محافظة بيروت  5c3f5eb24a1cc0002cd18f87
# 18      محافظة بيروت  4c8e77b9daa93704acea4cb1
# 19               NaN  52fd0ddf498e4d337917c8d0
# 20      محافظة بيروت  4cf3f95fd29b2d43c453f3bb
# 21               NaN  4f8c14e6e4b002b90dabb51f
# 22        Mt Lebanon  4e8f407393adc15b61950d21
# 23               NaN  589ec2d80bc55b3d8224ee1b
# 24  محافظة جبل لبنان  55630503498e6647f30c1052
# 25        Mt Lebanon  4e0091ee1f6ef39c294048b3
# 26      محافظة بيروت  597056e4033693233bb27723
# 27      محافظة بيروت  523199cb11d279f8d29ad3f3
# 28               NaN  4f441e12e4b06bcb6d7d4b2b
# 29               NaN  51ed32b0498e58679fb93ee8

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the my address

# add the fitness centres as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered['categories'].value_counts()
# Out:
# Gym                     14
# Gym / Fitness Center     9
# Athletics & Sports       2
# Office                   1
# Juice Bar                1
# Pilates Studio           1
# Café                     1
# Bathing Area             1
# Name: categories, dtype: int64

# %% [markdown]
# ## Results

# %% [markdown]
# As is clear in the above dataframe, Beirut has approximately 25 fitness centres. There is a clear correlation between the number of gyms in and the level of poverty in the said area. Unfortunately data for poverty levels by area is unavailable, but the areas with the least number of gyms, Chiyah, Ghobeiry, Sin el Fil, and Corniche el Mazraa clearly have very few gyms.

# %% [markdown]
# ## Discussion

# %% [markdown]
# There is the obvious issue that many of these areas are poorly served by Foursquare data collectors. It is likely that gyms do exist in these regions, but are simply not listed. However, if we use listing on Foursquare as a proxy for the quality of the gym, the conclusion can be made that the areas listed above are the most underserved of quality gyms.
#
# It can thus be concluded that if a high-quality gym was set up in one of those areas with a buisiness model that properly targets the residents of that area, it would be a s
# uccess.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, I used the Foursquare API to see which areas of Beirut have the least number of fitness centres and hence recommend potential locations for a new gym.
